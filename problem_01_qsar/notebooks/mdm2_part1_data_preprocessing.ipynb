# %% [markdown]
# <a href="https://colab.research.google.com/github/Maryam-Taherzadeh/Computational-Drug-Discovery/blob/main/problem_01_qsar/notebooks/mdm2_part1_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
# ## Project Overview
#
# In this Jupyter Notebook, we develop a real-world data science project focused on drug discovery. The goal is to build a machine learning model using bioactivity data obtained from the ChEMBL database.
#
# This project demonstrates how computational methods can be applied to predict the biological activity of chemical compounds, enabling more efficient identification of potential drug candidates.
#
# ## Objectives
#
# - Retrieve and preprocess bioactivity data from ChEMBL
# - Convert molecular structures (SMILES) into numerical features using RDKit
# - Perform exploratory data analysis (EDA)
# - Train machine learning models to predict molecular activity (e.g., IC50)
# - Evaluate model performance using appropriate metrics
#
# ## Applications
#
# This workflow is widely used in:
# - Drug discovery
# - QSAR/QSPR modeling
# - Virtual screening pipelines
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ### **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**
# ###Install ChEMBL Web Resource Client
#
# In this step, we install the ChEMBL web resource client, which allows us to retrieve bioactivity data directly from the ChEMBL.
#
# This client provides a convenient interface to access:
#
# * molecular data
# * bioactivity data (e.g., IC50)
# * target information

# %%
! pip install chembl_webresource_client

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries

import pandas as pd
# !pip install chembl_webresource_client --upgrade
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ## **Search for MDM2**

# %%
target = new_client.target
target_query = target.search('MDM2')
targets = pd.DataFrame.from_dict(target_query)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

targets
# Out:
#    cross_references                organism  \
# 0                []            Homo sapiens
# 1                []  Canis lupus familiaris
# 2                []            Mus musculus
# 3                []            Homo sapiens
# 4                []            Homo sapiens
# 5                []            Homo sapiens
# 6                []            Homo sapiens
# 7                []            Homo sapiens
# 8                []            Homo sapiens
# 9                []            Homo sapiens
# 10               []            Homo sapiens
# 11               []            Homo sapiens
# 12               []            Homo sapiens
# 13               []            Homo sapiens
# 14               []            Homo sapiens
# 15               []            Homo sapiens
# 16               []            Homo sapiens
# 17               []            Homo sapiens
# 18               []            Homo sapiens
#
#                                             pref_name  score  \
# ...

# %% [markdown]
# # Select and retrieve bioactivity data for MDM2-p53 interaction target
#
# ---

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *tumour suppressor p53/oncoprotein Mdm2*) to the **selected_target** variable.

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL1907611'

# %% [markdown]
# Here, we retrieve bioactivity data for the *p53–MDM2 interaction target* (CHEMBL1907611), focusing on compounds with experimentally measured **IC50 values reported in nanomolar (nM) units**, which will be used to assess inhibitory activity.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(10)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1424130                  []
# 1        None             None      1424131                  []
# 2        None             None      1424132                  []
# 3        None             None      1424135                  []
# 4        None             None      1424136                  []
# 5        None             None      1424137                  []
# 6        None             None      1424233                  []
# 7        None             None      1424234                  []
# 8        None             None      1424235                  []
# 9        None             None      1424236                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL828042  Inhibitory concentration against MDM2-p53 inte...
# 1    CHEMBL828042  Inhibitory concentration against MDM2-p53 inte...
# ...

# %%
#It returns all different activity types in your dataset.
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.shape
# Out:
# (1820, 46)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **mdm2_data.csv**.

# %%
# save it locally
df.to_csv('mdm2_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
# create folder safely
# !mkdir -p "/content/gdrive/My Drive/Colab Notebooks/data2"
# copy file into folder
# !cp mdm2_data.csv "/content/gdrive/My Drive/Colab Notebooks/data2"
# list files
# !ls "/content/gdrive/My Drive/Colab Notebooks/data2"
# show detail info
# !ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# !pwd
# Out:
# mdm2_data.csv
# total 175
# -rw------- 1 root root 178896 Apr 16 00:41 mdm2_preprocessed_data.csv
# /content

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
# !ls
# Out:
# gdrive	mdm2_data.csv  mdm2_preprocessed_data.csv  sample_data

# %% [markdown]
# Taking a glimpse of the **mdm2_data.csv.csv** file that we've just created.

# %%
! head mdm2_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df.standard_value.isna().sum()
# Out:
# np.int64(0)

# %%
df2 = df[df.standard_value.notna()]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))

df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %% [markdown]
# Saves dataframe to CSV *file*

# %%
df3.to_csv('mdm2_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 2556
# drwx------ 5 root root    4096 Apr 16 00:41 gdrive
# -rw-r--r-- 1 root root 2427770 Apr 15 16:53 mdm2_data.csv
# -rw-r--r-- 1 root root  178896 Apr 16 01:50 mdm2_preprocessed_data.csv
# drwxr-xr-x 1 root root    4096 Apr  2 13:31 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp mdm2_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
! cp mdm2_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mdm2_data.csv  mdm2_preprocessed_data.csv

# %% [markdown]
# ---
